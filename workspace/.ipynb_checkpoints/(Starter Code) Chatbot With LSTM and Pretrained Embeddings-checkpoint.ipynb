# %% [markdown]
# # LSTM Bot
#
# ## Project Overview
#
# In this project, you will build a chatbot that can converse with you at the command line. The chatbot will use a Sequence to Sequence text generation architecture with an LSTM as it's memory unit. You will also learn to use pretrained word embeddings to improve the performance of the model. At the conclusion of the project, you will be able to show your chatbot to potential employers.
#
# Additionally, you have the option to use pretrained word embeddings in your model. We have loaded Brown Embeddings from Gensim in the starter code below. You can compare the performance of your model with pre-trained embeddings against a model without the embeddings.
#
#
#
# ---
#
#
#
# A sequence to sequence model (Seq2Seq) has two components:
# - An Encoder consisting of an embedding layer and LSTM unit.
# - A Decoder consisting of an embedding layer, LSTM unit, and linear output unit.
#
# The Seq2Seq model works by accepting an input into the Encoder, passing the hidden state from the Encoder to the Decoder, which the Decoder uses to output a series of token predictions.
#
# ## Dependencies
#
# - Pytorch
# - Numpy
# - Pandas
# - NLTK
# - Gzip
# - Gensim
#
#
# Please choose a dataset from the Torchtext website. We recommend looking at the Squad dataset first. Here is a link to the website where you can view your options:
#
# - https://pytorch.org/text/stable/datasets.html

# %%
test = False
init = False

if test:
    # !pip install -U  pytest
if init:
    pass
    #!pip install torchsummary
    #!pip install typing-extensions --upgrade
    #!pip install -U torch torchvision torchtext torchdata pytest

# %%
# public libraries
import nltk
import numpy as np
import pandas as pd
import gzip
import torch
import torch.nn as nn
import pandas as pd
import torch.optim
import random
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt

# my libraries
import src.utils
import src.data

# %%
# create Proof-of-Concept dataset
df_names = pd.read_csv('data/names.csv')

poc_questions = []
poc_answers = []
for i, row in list(df_names.iterrows())[:90]:
    poc_questions.append("What is your name?")
    name = row["First Name"]+" "+row["Last Name"]
    poc_answers.append(f"'My name is {name}'")
for i, row in list(df_names.iterrows())[90:]:
    poc_questions.append("What is your name?")
    name = row["First Name"]+" "+row["Last Name"]
    poc_answers.append(f"['{name}']")
for i in range(100):
    poc_questions.append("What is your name?")
    one = random.randint(0,99)
    two = random.randint(0,99)
    name_one = df_names["First Name"].iloc[one]+" "+df_names["Last Name"].iloc[two]
    name_two = df_names["First Name"].iloc[two]+" "+df_names["Last Name"].iloc[two]
    poc_answers.append(f"['Our name is {name_one} and {name_two}']")
for i, row in list(df_names.iterrows()):
    poc_questions.append("What is her name?")
    name = row["First Name"]+" "+row["Last Name"]
    if row["Gender"] == "Female":
        poc_answers.append(f"['Her name is {name}']")
for i, row in list(df_names.iterrows()):
    poc_questions.append("What is his name?")
    name = row["First Name"]+" "+row["Last Name"]
    if row["Gender"] == "Male":
        poc_answers.append(f"['His name is {name}']'")
df_poc = pd.DataFrame(list(zip(poc_questions, poc_answers)),
               columns =['question', 'answer'])
df_poc.to_csv('data/poc_data.csv')

# %%
if False:
    from nltk.corpus import brown
    from nltk.tokenize import RegexpTokenizer
    import gensim


    #from ntlk.stem import *

    nltk.download('brown')
    nltk.download('punkt')

    # Output, save, and load brown embeddings

    model = gensim.models.Word2Vec(brown.sents())
    model.save('brown.embedding')

    w2v = gensim.models.Word2Vec.load('brown.embedding')



    def loadDF(path):
      '''

      You will use this function to load the dataset into a Pandas Dataframe for processing.

      '''
      return df


    def prepare_text(sentence):

        '''

        Our text needs to be cleaned with a tokenizer. This function will perform that task.
        https://www.nltk.org/api/nltk.tokenize.html

        '''

        return tokens



    def train_test_split(SRC, TRG):

        '''
        Input: SRC, our list of questions from the dataset
                TRG, our list of responses from the dataset

        Output: Training and test datasets for SRC & TRG

        '''
        share = 0.2
        src_split = len(SRC)*share
        trg_split = len(TRG)*share
        SRC_test_dataset = SRC[:scr_split]
        SRC_train_dataset = SRC[scr_split:]
        TRG_test_dataset = SRC[:trg_split]
        TRG_train_dataset = SRC[trg_split:]


        return SRC_train_dataset, SRC_test_dataset, TRG_train_dataset, TRG_test_dataset

# %% [markdown]
# ### Get and watch the data

# %%
if init:
    data.squad1_to_csv()
    
# df_train = pd.read_csv('data/train_dataset_squad1.csv')  
df_train = pd.read_csv('data/poc_data.csv')  
# df_test = pd.read_csv('data/dev_dataset_squad1.csv') 
df_test = pd.read_csv('data/poc_data.csv')
split = round(len(df_train)*100/(len(df_train)+len(df_test)),1)
print(f"{len(df_train)} training samples and {len(df_test)} have been loaded.")
print(f"The test data makes {split}% of all the data.")
df_train.head()
# Out:
# 300 training samples and 300 have been loaded.
# The test data makes 50.0% of all the data.
#    Unnamed: 0            question                        answer
# 0           0  What is your name?  'My name is Vanessa Elliott'
# 1           1  What is your name?    'My name is Ada Henderson'
# 2           2  What is your name?     'My name is Daniel Grant'
# 3           3  What is your name?    'My name is Lydia Carroll'
# 4           4  What is your name?       'My name is John Scott'

# %% [markdown]
# ### Data Analysis

# %%
vocab_prep = src.utils.Vocab(name='prepration')
raw_questions = [vocab_prep.clean_text(s) for s in df_train["question"].values.tolist()]
raw_answers = [vocab_prep.clean_text(q[2:-2]) for q in df_train["answer"].values.tolist()]

# %%
# Source Data
plt.title("Distribution of lengths of questions")
plt.hist(np.array([len(n) for n in raw_questions]))
# Out:
# (array([  0.,   0.,   0.,   0.,   0., 300.,   0.,   0.,   0.,   0.]),
#  array([3.5, 3.6, 3.7, 3.8, 3.9, 4. , 4.1, 4.2, 4.3, 4.4, 4.5]),
#  <BarContainer object of 10 artists>)

# %%
# Target Data
plt.title("Distribution of lengths of answers")
plt.hist(np.array([len(n) for n in raw_answers]))
# Out:
# (array([ 10.,   0.,   0.,   0.,   0., 190.,   0.,   0.,   0., 100.]),
#  array([2. , 2.6, 3.2, 3.8, 4.4, 5. , 5.6, 6.2, 6.8, 7.4, 8. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### Filtering out of noise
#
# I remove all questions with less than 25 words and all answers with less than 13 words (together with their counterpart).

# %%
index_a = [index for index, row in enumerate(raw_questions) if len(row) < 25]
index_b = [index for index, row in enumerate(raw_answers) if len(row) < 13]

index_all=list(set(index_a).intersection(set(index_b)))
share = round(((len(df_train)-len(index_all))/len(df_train))*100,1)
df_train_filtered = df_train.iloc[index_all]
print(f"We have removed {share}% of the data.")
# Out:
# We have removed 0.0% of the data.

# %% [markdown]
# ### Tokenization

# %%
# we have to repeat this step with the filtered dataframe
raw_questions = [vocab_prep.clean_text(s) for s in df_train_filtered["question"].values.tolist()]
raw_answers = [vocab_prep.clean_text(q[2:-2]) for q in df_train_filtered["answer"].values.tolist()]

# %%
sequence_length_source = src.utils.get_max_length(raw_questions) + 2
sequence_length_target = src.utils.get_max_length(raw_answers) + 1
print(f"The source sequence has to have a length of {sequence_length_source}. And the target sequence has to have a length of {sequence_length_target}.")
# Out:
# The source sequence has to have a length of 6. And the target sequence has to have a length of 9.

# %%
vocab_source = src.utils.Vocab(name='source')
vocab_target = src.utils.Vocab(name='target')

count = 0
for q, a in zip(raw_questions, raw_answers):

    PAD = "<PAD>"
    SOS = "<SOS>"
    EOS = "<EOS>"
    OUT = "<OUT>"
    special_tokens = ["<PAD>", "<SOS>", "<EOS>", "<OUT>"]
    for word in special_tokens + q:
        vocab_source.indexWord(word)
    for word in special_tokens + a:
        vocab_target.indexWord(word)

print("source:", len(vocab_source.words), "target:", len(vocab_target.words), "common words:", len(list(set(vocab_source.words.keys()).intersection(set(vocab_target.words.keys())))))

questions = src.utils.tokenize_questions(raw_questions, vocab_source)
answers = src.utils.tokenize_answers(raw_answers, vocab_target)
# Out:
# source: 9 target: 206 common words: 6

# %% [markdown]
# ### Tests

# %%
if test:
    # !python -m pytest -vv tests.py

# %% [markdown]
# ### Defining the model

# %%
import torch.nn as nn
class Encoder(nn.Module):
    
    def __init__(self, input_size, hidden_size):
        
        super(Encoder, self).__init__()
        
        # self.embedding provides a vector representation of the inputs to our model
        self.embedding = nn.Embedding(input_size, hidden_size)
        
        # self.lstm, accepts the vectorized input and passes a hidden state
        self.lstm = nn.LSTM(hidden_size, hidden_size)
        self.dropout = nn.Dropout(p=0.0)
        
    
    def forward(self, i, h):
        
        '''
        Inputs: i, the src vector
        Outputs: o, the encoder outputs
                h, the hidden state (actually a tuple of hidden state and cell state)
        '''
        embedding = self.embedding(i)
        x,y = h
        o, h= self.lstm(embedding, h)
        o = self.dropout(o)
        
        return o, h
    

class Decoder(nn.Module):
      
    def __init__(self, hidden_size, output_size):
        
        super(Decoder, self).__init__()
        
        # self.embedding provides a vector representation of the target to our model
        self.embedding = nn.Embedding(output_size, hidden_size)
        
        # self.lstm, accepts the embeddings and outputs a hidden state
        self.lstm = nn.LSTM(hidden_size, hidden_size)

        # self.ouput, predicts on the hidden state via a linear output layer  
        self.linear = nn.Linear(hidden_size, output_size)
        
        self.softmax = nn.Softmax(dim=1)
        
    def forward(self, i, h):
        
        '''
        Inputs: i, the target vector
        Outputs: o, the decoder output
                h, the hidden state (actually a tuple of hidden state and cell state)
        '''

        embedding = self.embedding(i)

        o, h = self.lstm(embedding, h)

        o = self.linear(o)

        o = self.softmax(o)

        
        return o, h
        
        

class Seq2Seq(nn.Module):
    
    def __init__(self, input_size, hidden_size, output_size):
        
        super(Seq2Seq, self).__init__()
        self.encoder = Encoder(input_size, hidden_size)
        self.decoder = Decoder(hidden_size, output_size)
                
        
    
    
    def forward(self, src, trg, start, teacher_forcing_ratio = 0.5): 
        '''
        Inputs: src, the source vector
                trg, the target vector
        Outputs: o, the prediction
                
        '''
        device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        src.to(device)
        trg.to(device)
        start.to(device)
        
            
        
        # encoder
        hidden = (torch.zeros(1,hidden_size).to(device), torch.zeros(1,hidden_size).to(device))
        for word in src:
            #print("word",word.shape,word)
            o, hidden = self.encoder(word.view(-1).to(device), hidden)
        
        # decoder
        o = start
        
        prediction = []
        for word in trg:
            #print("o", o)
            #print("o.view(-1)",o.view(-1))
            o, hidden = self.decoder(o.view(-1).to(device), hidden)
            prediction.append(o)

            if self.training:
                o = word if random.random() < teacher_forcing_ratio else torch.argmax(o,dim=1)
            else:
                o = torch.argmax(o,dim=1)
            

            
        
        return torch.stack(prediction).squeeze(1)

# %% [markdown]
# ### Training

# %%
len(raw_answers)
questions = src.utils.tokenize_questions(raw_questions, vocab_source)
answers = src.utils.tokenize_answers(raw_answers, vocab_target)

# %%
answers.shape
# Out:
# torch.Size([300, 9])

# %%
batch_size = 32
loader = DataLoader(list(zip(raw_questions, raw_answers)), shuffle = False, batch_size = batch_size)
print(len(loader))
# Out:
# 10

# %%
from pathlib import Path

questions = src.utils.tokenize_questions(raw_questions, vocab_source)
answers = src.utils.tokenize_answers(raw_answers, vocab_target)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
is_cuda = torch.cuda.is_available()
#is_cuda = False
print("is cuda:",is_cuda)


# hyperparams
epochs = 100

batch_size = 32
hidden_size = 64
lr = 0.01
teacher_forcing_ratio = 0.5
print_each = 2


loader  = DataLoader(list(zip(questions, answers)), shuffle = False, batch_size = batch_size)

#print(loader.shape)


# model
input_size = len(vocab_source.words)
hidden_size = hidden_size
output_size = len(vocab_target.words)
model = Seq2Seq(input_size, hidden_size, output_size)


# if Path("./checkpoints/model_1.pt").is_file():
#     model.load_state_dict(torch.load("./checkpoints/model_1.pt"))
#     print("loading from checkpoint: ''./checkpoints/model_1.pt'")
# else:
#     print("nothing to load at checkpoint: './checkpoints/model_1.pt'")

model.to(device)
# training

optim = torch.optim.SGD(model.parameters(), lr=lr)
loss_fn = nn.NLLLoss()
model.train()
epoch = 0
for epoch in range(epochs):

    for batch_i, (questions, answers) in enumerate(loader):
        batch_loss = 0
        #outputs = []
        for q, a in zip(questions, answers):       
            start = next(iter(torch.LongTensor([vocab_target.words["<SOS>"]])))
            optim.zero_grad()
            output = model(q,a,start)
            
            rand = random.uniform(0,1)
            loss = loss_fn(output, a.to(device))
            loss.backward(retain_graph=True)
            optim.step()
            batch_loss += loss.item()
            #outputs.append([output])
        if batch_i % print_each == 0:
            share = round(((batch_i+print_each)*100)/len(loader),1)
            print(" ")
            print("epoch", epoch, "batch#",batch_i,"batch loss:",batch_loss/batch_size, f"{share}% samples processed")
            text = ""
            for x in q:
                text += vocab_source.index[str(x.item())] + " "
            print("question",text)
            text = ""
            for x in a:
                #print(x)
                text += vocab_target.index[str(x.item())] + " "
            print("answer:", text)
            text = ""
            for x in output:
                #print(x)
                text += vocab_target.index[str(torch.argmax(x,dim=0).item())] + " "
            print("prediction:", text)
        if batch_i % 200 == 0:
            torch.save(model.state_dict(),"./checkpoints/model_1.pt")
# Out:
# is cuda: True
#
# epoch 0 batch# 0 batch loss: -0.004739567142678425 20.0% samples processed
# question <SOS> What is your name <EOS>
# answer: y name is Arthur Carte <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Richards Davi Morris Richards Richards Vincent Annabella Vincent
#
# epoch 0 batch# 2 batch loss: -0.004730264641693793 40.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Dale Phillips <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# prediction: Mason Thoma Stella Vincent Annabella Vincent Stuart Warre Warre
#
# epoch 0 batch# 4 batch loss: -0.00488857613527216 60.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Our name is Dominik Allen and Camila Allen <EOS>
# prediction: Mason Cadie Carte Kelle Sullivan William Eleanor Sullivan Morris
#
# epoch 0 batch# 6 batch loss: -0.004857486812397838 80.0% samples processed
# question <SOS> What is her name <EOS>
# answer: Her name is Stella Phillips <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Mason Cadie Carte Vivian Grace is Kelle Stuart
#
# epoch 0 batch# 8 batch loss: -0.004858185158809647 100.0% samples processed
# question <SOS> What is her name <EOS>
# answer: His name is Richard Parker <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Richard Stella <EOS> Carte Kelle Carte Carte Kelle
#
# epoch 1 batch# 0 batch loss: -0.004765497549669817 20.0% samples processed
# question <SOS> What is your name <EOS>
# answer: y name is Arthur Carte <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Richards Davi Morris Sulliva Kelle Sullivan Brook Brook
#
# epoch 1 batch# 2 batch loss: -0.004752746812300757 40.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Dale Phillips <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# prediction: Mason Thoma Watson Eleanor Eleanor Stuart Stuart Stuart Warre
#
# epoch 1 batch# 4 batch loss: -0.0049043299950426444 60.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Our name is Dominik Allen and Camila Allen <EOS>
# prediction: Mason Allen Owen Sullivan Carte William Robert Sullivan Sawyer
#
# epoch 1 batch# 6 batch loss: -0.004901820168015547 80.0% samples processed
# question <SOS> What is her name <EOS>
# answer: Her name is Stella Phillips <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Cadie Davi Morris Morris Allen Owen Vivian Vivian
#
# epoch 1 batch# 8 batch loss: -0.004871160912443884 100.0% samples processed
# question <SOS> What is her name <EOS>
# answer: His name is Richard Parker <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Cadie Carte Richards Richards Rebecca Cherry Cherry Carte
#
# epoch 2 batch# 0 batch loss: -0.00478458873112686 20.0% samples processed
# question <SOS> What is your name <EOS>
# answer: y name is Arthur Carte <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Richards Richards Elliot Richards Vincent Vincent Stuart Stuart
#
# epoch 2 batch# 2 batch loss: -0.004773203807417303 40.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Dale Phillips <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# prediction: Mason Thoma Watson Eleanor Eleanor Sullivan Fowle William Parker
#
# epoch 2 batch# 4 batch loss: -0.004904357279883698 60.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Our name is Dominik Allen and Camila Allen <EOS>
# prediction: Mason Allen Owen Vivian Grace Owen Vincent is Sullivan
#
# epoch 2 batch# 6 batch loss: -0.004893171528237872 80.0% samples processed
# question <SOS> What is her name <EOS>
# answer: Her name is Stella Phillips <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Cadie Carte Richards Richards Vivian Cole Kelle Stuart
#
# epoch 2 batch# 8 batch loss: -0.004839035202166997 100.0% samples processed
# question <SOS> What is her name <EOS>
# answer: His name is Richard Parker <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Cadie Carte Kelle Her Carter Mason Carter Kelle
#
# epoch 3 batch# 0 batch loss: -0.004836198742850684 20.0% samples processed
# question <SOS> What is your name <EOS>
# answer: y name is Arthur Carte <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Cadie Carte Kelle Sullivan Kelle Eleanor Sullivan Brook
#
# epoch 3 batch# 2 batch loss: -0.004759627510793507 40.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Dale Phillips <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# prediction: Mason Thoma Watson Richards Richards Kelle Sullivan Brook Brook
#
# epoch 3 batch# 4 batch loss: -0.004898149520158768 60.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Our name is Dominik Allen and Camila Allen <EOS>
# prediction: Mason Allen Owen Sullivan Carte Kelle Vincent Annabella Vincent
#
# epoch 3 batch# 6 batch loss: -0.004898589555523358 80.0% samples processed
# question <SOS> What is her name <EOS>
# answer: Her name is Stella Phillips <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Mason Cadie Carte Vivian Vivian Vivian James Morris
#
# epoch 3 batch# 8 batch loss: -0.004904655797872692 100.0% samples processed
# question <SOS> What is her name <EOS>
# answer: His name is Richard Parker <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Cadie Davi <EOS> Carte Carte Carte Carte Kelle
#
# epoch 4 batch# 0 batch loss: -0.004849462042329833 20.0% samples processed
# question <SOS> What is your name <EOS>
# answer: y name is Arthur Carte <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Cadie Carte Kelle Sullivan <EOS> Eleanor Clar Clark
#
# epoch 4 batch# 2 batch loss: -0.004782304706168361 40.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Dale Phillips <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# prediction: Mason Cadie Carte Carte Carte Kelle Kelle Sullivan Stuart
#
# epoch 4 batch# 4 batch loss: -0.004855602455791086 60.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Our name is Dominik Allen and Camila Allen <EOS>
# prediction: Mason Allen Richard Her Carter Mason Carter Patrick Owen
#
# epoch 4 batch# 6 batch loss: -0.0049178228073287755 80.0% samples processed
# question <SOS> What is her name <EOS>
# answer: Her name is Stella Phillips <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Mason Dougla <EOS> Allen Vivian Vincent Annabella Vincent
#
# epoch 4 batch# 8 batch loss: -0.0049044627958210185 100.0% samples processed
# question <SOS> What is her name <EOS>
# answer: His name is Richard Parker <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Richard Stella <EOS> Carte Kelle Carte Carte Kelle
#
# epoch 5 batch# 0 batch loss: -0.00483495976368431 20.0% samples processed
# question <SOS> What is your name <EOS>
# answer: y name is Arthur Carte <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Cadie Carte <EOS> Carte Kelle Sullivan Brook Ellis
#
# epoch 5 batch# 2 batch loss: -0.004786658682860434 40.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Dale Phillips <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# prediction: Mason Thoma Stella Vivian Vivian Stuart Carter Annabella Stuart
#
# epoch 5 batch# 4 batch loss: -0.0049182818911504 60.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Our name is Dominik Allen and Camila Allen <EOS>
# prediction: Mason Allen Richard Her Carte Kelle Sullivan Sullivan Ada
#
# epoch 5 batch# 6 batch loss: -0.004921693616779521 80.0% samples processed
# question <SOS> What is her name <EOS>
# answer: Her name is Stella Phillips <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Mason Dougla <EOS> Carte Vivian James Morris Carte
#
# epoch 5 batch# 8 batch loss: -0.0049057924770750105 100.0% samples processed
# question <SOS> What is her name <EOS>
# answer: His name is Richard Parker <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Richard Stella <EOS> <EOS> Cherry Cherry Carte Kelle
#
# epoch 6 batch# 0 batch loss: -0.0048383026296505705 20.0% samples processed
# question <SOS> What is your name <EOS>
# answer: y name is Arthur Carte <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Richards Richards Richards Richards Richards Vincent Russel Elliot
#
# epoch 6 batch# 2 batch loss: -0.004830960635445081 40.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Dale Phillips <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# prediction: Mason Thoma Stella Vivian Grace Kelle Stuart Warre Kelle
#
# epoch 6 batch# 4 batch loss: -0.004917376791127026 60.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Our name is Dominik Allen and Camila Allen <EOS>
# prediction: Mason Allen Richard Her Carte Kelle Sullivan Sullivan Taylo
#
# epoch 6 batch# 6 batch loss: -0.004959259968018159 80.0% samples processed
# question <SOS> What is her name <EOS>
# answer: Her name is Stella Phillips <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Mason Cadie Carte Vivian Vivian Vivian Vivian Stuart
#
# epoch 6 batch# 8 batch loss: -0.0049613933224463835 100.0% samples processed
# question <SOS> What is her name <EOS>
# answer: His name is Richard Parker <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Cadie Davi <EOS> <EOS> Cherry Cherry Vincent Carte
#
# epoch 7 batch# 0 batch loss: -0.004834511084482074 20.0% samples processed
# question <SOS> What is your name <EOS>
# answer: y name is Arthur Carte <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Richards Richards Richards Richards Kelle Eleanor Sullivan Sullivan
#
# epoch 7 batch# 2 batch loss: -0.004807439487194642 40.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Dale Phillips <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# prediction: Mason Thoma Stella Vincent Annabella Vincent Stuart Stuart Warre
#
# epoch 7 batch# 4 batch loss: -0.004938793776091188 60.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Our name is Dominik Allen and Camila Allen <EOS>
# prediction: Mason Allen Owen Sullivan Carte William Vincent Annabella Owen
#
# epoch 7 batch# 6 batch loss: -0.004958745295880362 80.0% samples processed
# question <SOS> What is her name <EOS>
# answer: Her name is Stella Phillips <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Mason Cadie <EOS> Richards Richards Vincent Annabella Annabella
#
# epoch 7 batch# 8 batch loss: -0.004937287885695696 100.0% samples processed
# question <SOS> What is her name <EOS>
# answer: His name is Richard Parker <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Richard Her Carter Her Cherry <EOS> Carter Kelle
#
# epoch 8 batch# 0 batch loss: -0.004915442565106787 20.0% samples processed
# question <SOS> What is your name <EOS>
# answer: y name is Arthur Carte <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Richards Davi Morris Sulliva <EOS> Eleanor Sullivan <EOS>
#
# epoch 8 batch# 2 batch loss: -0.004830684541957453 40.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Dale Phillips <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# prediction: Mason Cadie Vivian Eleanor Sullivan Fowle William Kelle Sullivan
#
# epoch 8 batch# 4 batch loss: -0.00494527310365811 60.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Our name is Dominik Allen and Camila Allen <EOS>
# prediction: Mason Cadie Davi Morris Carte Kelle Vincent Vincent Brianna
#
# epoch 8 batch# 6 batch loss: -0.004930411392706446 80.0% samples processed
# question <SOS> What is her name <EOS>
# answer: Her name is Stella Phillips <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Mason Cadie Carte Kelle Vivian Vincent Carte Stuart
#
# epoch 8 batch# 8 batch loss: -0.004901006570435129 100.0% samples processed
# question <SOS> What is her name <EOS>
# answer: His name is Richard Parker <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Cadie Carte Kelle Her Carter Vincent Annabella Annabella
#
# epoch 9 batch# 0 batch loss: -0.004885255068074912 20.0% samples processed
# question <SOS> What is your name <EOS>
# answer: y name is Arthur Carte <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Richards Davi <EOS> Stuart Kelle Eleanor Sullivan Sullivan
#
# epoch 9 batch# 2 batch loss: -0.0048468811000930145 40.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Dale Phillips <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# prediction: Mason Thoma Stella Vincent Carter Kelle Annabella Vincent Stuart
#
# epoch 9 batch# 4 batch loss: -0.004925871849991381 60.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Our name is Dominik Allen and Camila Allen <EOS>
# prediction: Mason Cadie Carte Kelle Carte William Eleanor Sullivan Brianna
#
# epoch 9 batch# 6 batch loss: -0.004939428836223669 80.0% samples processed
# question <SOS> What is her name <EOS>
# answer: Her name is Stella Phillips <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Mason Dougla <EOS> Fowle James Vincent Annabella Vincent
#
# epoch 9 batch# 8 batch loss: -0.004972187729435973 100.0% samples processed
# question <SOS> What is her name <EOS>
# answer: His name is Richard Parker <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Cadie Dougla <EOS> Carte Carte Carte Carte Kelle
#
# epoch 10 batch# 0 batch loss: -0.0048948900803225115 20.0% samples processed
# question <SOS> What is your name <EOS>
# answer: y name is Arthur Carte <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Cadie Davi <EOS> Carte Kelle Carte Carte Kelle
#
# epoch 10 batch# 2 batch loss: -0.004844063165364787 40.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Dale Phillips <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# prediction: Mason Thoma Watson Eleanor Eleanor Sullivan Sullivan Brook Brook
#
# epoch 10 batch# 4 batch loss: -0.004938562429742888 60.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Our name is Dominik Allen and Camila Allen <EOS>
# prediction: Mason Allen Richard Her Carter Mason Carter Mason Richards
#
# epoch 10 batch# 6 batch loss: -0.004955922471708618 80.0% samples processed
# question <SOS> What is her name <EOS>
# answer: Her name is Stella Phillips <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Cadie Dougla <EOS> Carte Vivian James Morris Carte
#
# epoch 10 batch# 8 batch loss: -0.0049999195325654 100.0% samples processed
# question <SOS> What is her name <EOS>
# answer: His name is Richard Parker <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Cadie Carte Kelle Sullivan <EOS> Carte Carte Kelle
#
# epoch 11 batch# 0 batch loss: -0.004922047475702129 20.0% samples processed
# question <SOS> What is your name <EOS>
# answer: y name is Arthur Carte <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Cadie Davi Morris James Kelle Sullivan Stuart Stuart
#
# epoch 11 batch# 2 batch loss: -0.004903088163700886 40.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Dale Phillips <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# prediction: Mason Thoma Stella Vivian Grace is Kelle Sullivan Stuart
#
# epoch 11 batch# 4 batch loss: -0.0049171868013218045 60.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Our name is Dominik Allen and Camila Allen <EOS>
# prediction: Mason Allen Owen Sullivan <EOS> William Vincent is Owen
#
# epoch 11 batch# 6 batch loss: -0.004990421759430319 80.0% samples processed
# question <SOS> What is her name <EOS>
# answer: Her name is Stella Phillips <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Mason Dougla Richard <EOS> Higgin James Carter Stuart
#
# epoch 11 batch# 8 batch loss: -0.004934865937684663 100.0% samples processed
# question <SOS> What is her name <EOS>
# answer: His name is Richard Parker <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Richard Stella Ada Her Carter Eleanor Carter Kelle
#
# epoch 12 batch# 0 batch loss: -0.004946782370097935 20.0% samples processed
# question <SOS> What is your name <EOS>
# answer: y name is Arthur Carte <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Richards Richards Richards Richards Kelle Sullivan <EOS> Eleanor
#
# epoch 12 batch# 2 batch loss: -0.0049096954899141565 40.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Dale Phillips <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# prediction: Mason Thoma Stella Vivian Vivian Vivian James Kelle Kelle
#
# epoch 12 batch# 4 batch loss: -0.004967478875187226 60.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Our name is Dominik Allen and Camila Allen <EOS>
# prediction: Mason Cadie Davi Morris Carte Kelle Vincent Annabella Vincent
#
# epoch 12 batch# 6 batch loss: -0.005004103819373995 80.0% samples processed
# question <SOS> What is her name <EOS>
# answer: Her name is Stella Phillips <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Cadie Dougla <EOS> Carte Vivian James Kelle Stuart
#
# epoch 12 batch# 8 batch loss: -0.005025144506362267 100.0% samples processed
# question <SOS> What is her name <EOS>
# answer: His name is Richard Parker <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Cadie Dougla Richard <EOS> Carte Carte Kelle Kelle
#
# epoch 13 batch# 0 batch loss: -0.004955919983331114 20.0% samples processed
# question <SOS> What is your name <EOS>
# answer: y name is Arthur Carte <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Richards Richards Richards Richards Kelle Sullivan <EOS> Eleanor
#
# epoch 13 batch# 2 batch loss: -0.004919906627037562 40.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Dale Phillips <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# prediction: Mason Thoma Watson Richards Annabella Vincent Stuart Stuart Stuart
#
# epoch 13 batch# 4 batch loss: -0.004926269859424792 60.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Our name is Dominik Allen and Camila Allen <EOS>
# prediction: Mason Allen Owen Vivian Carter Kelle Sullivan Carter Kelle
#
# epoch 13 batch# 6 batch loss: -0.0050464760133763775 80.0% samples processed
# question <SOS> What is her name <EOS>
# answer: Her name is Stella Phillips <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Cadie Dougla <EOS> Carte Vivian James Morris Kelle
#
# epoch 13 batch# 8 batch loss: -0.004992912494344637 100.0% samples processed
# question <SOS> What is her name <EOS>
# answer: His name is Richard Parker <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Richard Her Davi Morris Sulliva <EOS> Kelle Tess
#
# epoch 14 batch# 0 batch loss: -0.004996270581614226 20.0% samples processed
# question <SOS> What is your name <EOS>
# answer: y name is Arthur Carte <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Cadie Carte Kelle Richards Vincent Vincent Annabella Vincent
#
# epoch 14 batch# 2 batch loss: -0.00494527563569136 40.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Dale Phillips <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# prediction: Mason Cadie Vivian James Morris Carte Brook Stuart Stuart
#
# epoch 14 batch# 4 batch loss: -0.0049422623560531065 60.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Our name is Dominik Allen and Camila Allen <EOS>
# prediction: Mason Cadie Carte Kelle Carte Kelle Sullivan Sullivan Ada
#
# epoch 14 batch# 6 batch loss: -0.005048589882790111 80.0% samples processed
# question <SOS> What is her name <EOS>
# answer: Her name is Stella Phillips <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Mason Dougla Richard <EOS> Higgin James Cherry Carter
#
# epoch 14 batch# 8 batch loss: -0.005066867845016532 100.0% samples processed
# question <SOS> What is her name <EOS>
# answer: His name is Richard Parker <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Cadie Dougla Richard <EOS> Carte Vincent Warre Higgin
#
# epoch 15 batch# 0 batch loss: -0.0049635573086561635 20.0% samples processed
# question <SOS> What is your name <EOS>
# answer: y name is Arthur Carte <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Cadie Dougla <EOS> Stuart Kelle Eleanor Carte Kelle
#
# epoch 15 batch# 2 batch loss: -0.004977291071554646 40.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Dale Phillips <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# prediction: Mason Cadie Carte Carte Carte Carte Kelle Sullivan Brook
#
# epoch 15 batch# 4 batch loss: -0.004985930630937219 60.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Our name is Dominik Allen and Camila Allen <EOS>
# prediction: Mason Allen Owen <EOS> Carte Kelle Sullivan Sullivan Taylo
#
# epoch 15 batch# 6 batch loss: -0.005069135062512942 80.0% samples processed
# question <SOS> What is her name <EOS>
# answer: Her name is Stella Phillips <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Cadie Dougla <EOS> Carte Kelle Sullivan Brook Brook
#
# epoch 15 batch# 8 batch loss: -0.004989289562217891 100.0% samples processed
# question <SOS> What is her name <EOS>
# answer: His name is Richard Parker <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Cadie Dougla <EOS> <EOS> Cherry <EOS> Carte Kelle
#
# epoch 16 batch# 0 batch loss: -0.0049850710784085095 20.0% samples processed
# question <SOS> What is your name <EOS>
# answer: y name is Arthur Carte <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Richards Davi Morris Sulliva <EOS> Eleanor Sullivan <EOS>
#
# epoch 16 batch# 2 batch loss: -0.004979352597729303 40.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Dale Phillips <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# prediction: Mason Thoma Watson Eleanor Sullivan Fowle William Parker Robert
#
# epoch 16 batch# 4 batch loss: -0.004969303772668354 60.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Our name is Dominik Allen and Camila Allen <EOS>
# prediction: Mason <EOS> Dougla Davi Morris <EOS> Eleanor Tucker Nelson
#
# epoch 16 batch# 6 batch loss: -0.005056187801528722 80.0% samples processed
# question <SOS> What is her name <EOS>
# answer: Her name is Stella Phillips <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Cadie Carte <EOS> Richards Richards Vincent Annabella Vincent
#
# epoch 16 batch# 8 batch loss: -0.005062875425210223 100.0% samples processed
# question <SOS> What is her name <EOS>
# answer: His name is Richard Parker <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Richard Stella Ada Nelson Tara Cherry James Sullivan
#
# epoch 17 batch# 0 batch loss: -0.004984765997505747 20.0% samples processed
# question <SOS> What is your name <EOS>
# answer: y name is Arthur Carte <EOS> <PAD> <PAD> <PAD>
# prediction: Mason <EOS> Dougla Davi Richard <EOS> Carte Carte Kelle
#
# epoch 17 batch# 2 batch loss: -0.00499007644248195 40.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Dale Phillips <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# prediction: Mason <EOS> Vivian Eleanor Sullivan Sullivan Stuart Warre Higgin
#
# epoch 17 batch# 4 batch loss: -0.005007447689422406 60.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Our name is Dominik Allen and Camila Allen <EOS>
# prediction: Mason <EOS> Dougla Davi Morris <EOS> Eleanor Sullivan Owen
#
# epoch 17 batch# 6 batch loss: -0.005080383023596369 80.0% samples processed
# question <SOS> What is her name <EOS>
# answer: Her name is Stella Phillips <EOS> <PAD> <PAD> <PAD>
# prediction: Mason <EOS> <EOS> Eleanor Sullivan <EOS> Eleanor Warre Higgin
#
# epoch 17 batch# 8 batch loss: -0.005069474631454796 100.0% samples processed
# question <SOS> What is her name <EOS>
# answer: His name is Richard Parker <EOS> <PAD> <PAD> <PAD>
# prediction: Mason <EOS> Eleanor Sullivan <EOS> Eleanor Clar Richards Sullivan
#
# epoch 18 batch# 0 batch loss: -0.00498852257442195 20.0% samples processed
# question <SOS> What is your name <EOS>
# answer: y name is Arthur Carte <EOS> <PAD> <PAD> <PAD>
# prediction: Mason <EOS> Dougla Davi Morris <EOS> Eleanor Eleanor Sullivan
#
# epoch 18 batch# 2 batch loss: -0.004985567487892695 40.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Dale Phillips <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# prediction: Mason is Stella Vincent James Cherry Higgin James Carter
#
# epoch 18 batch# 4 batch loss: -0.004984117389540188 60.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Our name is Dominik Allen and Camila Allen <EOS>
# prediction: Mason <EOS> Eleanor <EOS> Carte William Vincent Annabella Vincent
#
# epoch 18 batch# 6 batch loss: -0.005079131340608001 80.0% samples processed
# question <SOS> What is her name <EOS>
# answer: Her name is Stella Phillips <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Mason Dougla <EOS> Fowle James Morris Stuart Carter
#
# epoch 18 batch# 8 batch loss: -0.005095767250168137 100.0% samples processed
# question <SOS> What is her name <EOS>
# answer: His name is Richard Parker <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Richard <EOS> <EOS> Carte Cherry <EOS> Vincent Robert
#
# epoch 19 batch# 0 batch loss: -0.005035194117226638 20.0% samples processed
# question <SOS> What is your name <EOS>
# answer: y name is Arthur Carte <EOS> <PAD> <PAD> <PAD>
# prediction: Mason <EOS> Eleanor Sullivan <EOS> Eleanor Eleanor Clar Myer
#
# epoch 19 batch# 2 batch loss: -0.0049948334926739335 40.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Dale Phillips <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# prediction: Mason is Stella Vincent Carte Kelle Sullivan Brook Ellis
#
# epoch 19 batch# 4 batch loss: -0.004975141273462214 60.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Our name is Dominik Allen and Camila Allen <EOS>
# prediction: Mason <EOS> <EOS> Eleanor Sullivan <EOS> Eleanor Tucker William
#
# epoch 19 batch# 6 batch loss: -0.005082625240902416 80.0% samples processed
# question <SOS> What is her name <EOS>
# answer: Her name is Stella Phillips <EOS> <PAD> <PAD> <PAD>
# prediction: Mason <EOS> <EOS> Eleanor Sullivan <EOS> Eleanor Warre Higgin
#
# epoch 19 batch# 8 batch loss: -0.005089362326543778 100.0% samples processed
# question <SOS> What is her name <EOS>
# answer: His name is Richard Parker <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Richard <EOS> <EOS> Carte Cherry Cherry Carte Kelle
#
# epoch 20 batch# 0 batch loss: -0.0050407356466166675 20.0% samples processed
# question <SOS> What is your name <EOS>
# answer: y name is Arthur Carte <EOS> <PAD> <PAD> <PAD>
# prediction: Mason <EOS> Eleanor <EOS> Carte Kelle Eleanor Carte Kelle
#
# epoch 20 batch# 2 batch loss: -0.0050195861113024876 40.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Dale Phillips <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# prediction: Mason is Stella Vivian Vivian Stuart Warre Kelle Stuart
#
# epoch 20 batch# 4 batch loss: -0.0049833365774247795 60.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Our name is Dominik Allen and Camila Allen <EOS>
# prediction: Mason <EOS> Eleanor <EOS> Carte Kelle Vincent Annabella Owen
#
# epoch 20 batch# 6 batch loss: -0.0050555330235511065 80.0% samples processed
# question <SOS> What is her name <EOS>
# answer: Her name is Stella Phillips <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Mason Cadie <EOS> Richards Vivian Vincent Annabella Vincent
#
# epoch 20 batch# 8 batch loss: -0.005110971949761733 100.0% samples processed
# question <SOS> What is her name <EOS>
# answer: His name is Richard Parker <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Richard <EOS> <EOS> Carte Kelle Carte Carte Kelle
#
# epoch 21 batch# 0 batch loss: -0.0050471870781620964 20.0% samples processed
# question <SOS> What is your name <EOS>
# answer: y name is Arthur Carte <EOS> <PAD> <PAD> <PAD>
# prediction: Mason <EOS> <EOS> Eleanor Eleanor Sullivan <EOS> Eleanor Clar
#
# epoch 21 batch# 2 batch loss: -0.005020287775550969 40.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Dale Phillips <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# prediction: Mason <EOS> Vivian Eleanor Carte Stuart Carter Kelle Tess
#
# epoch 21 batch# 4 batch loss: -0.004991770620108582 60.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Our name is Dominik Allen and Camila Allen <EOS>
# prediction: Mason Allen Richard <EOS> Carte Kelle Vincent Annabella Owen
#
# epoch 21 batch# 6 batch loss: -0.005067655423772521 80.0% samples processed
# question <SOS> What is her name <EOS>
# answer: Her name is Stella Phillips <EOS> <PAD> <PAD> <PAD>
# prediction: Mason <EOS> <EOS> Eleanor Sullivan Vivian Eleanor Carter Stuart
#
# epoch 21 batch# 8 batch loss: -0.005146371986484155 100.0% samples processed
# question <SOS> What is her name <EOS>
# answer: His name is Richard Parker <EOS> <PAD> <PAD> <PAD>
# prediction: Mason <EOS> Eleanor Sullivan <EOS> Eleanor Clar Richards Sullivan
#
# epoch 22 batch# 0 batch loss: -0.005088171528768726 20.0% samples processed
# question <SOS> What is your name <EOS>
# answer: y name is Arthur Carte <EOS> <PAD> <PAD> <PAD>
# prediction: Mason <EOS> Eleanor Sullivan <EOS> Kelle <EOS> Brook Kelle
#
# epoch 22 batch# 2 batch loss: -0.005041358250309713 40.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Dale Phillips <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# prediction: Mason <EOS> Eleanor Sullivan <EOS> Eleanor Clar Richards Richards
#
# epoch 22 batch# 4 batch loss: -0.0050313323008595034 60.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Our name is Dominik Allen and Camila Allen <EOS>
# prediction: Mason Allen Owen Vivian Carter William Vincent is Sullivan
#
# epoch 22 batch# 6 batch loss: -0.005131832222105004 80.0% samples processed
# question <SOS> What is her name <EOS>
# answer: Her name is Stella Phillips <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Mason Dougla <EOS> Carte Kelle Sullivan Stuart Stuart
#
# epoch 22 batch# 8 batch loss: -0.0051331162540009245 100.0% samples processed
# question <SOS> What is her name <EOS>
# answer: His name is Richard Parker <EOS> <PAD> <PAD> <PAD>
# prediction: Mason <EOS> <EOS> Eleanor Cherry <EOS> Vincent Carter Carter
#
# epoch 23 batch# 0 batch loss: -0.00507070250750985 20.0% samples processed
# question <SOS> What is your name <EOS>
# answer: y name is Arthur Carte <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Richards Richards <EOS> <EOS> Kelle Sullivan Stuart Carter
#
# epoch 23 batch# 2 batch loss: -0.00504474931221921 40.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Dale Phillips <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# prediction: Mason <EOS> Vivian Eleanor Carte Stuart Carter Kelle Kelle
#
# epoch 23 batch# 4 batch loss: -0.005016460796468891 60.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Our name is Dominik Allen and Camila Allen <EOS>
# prediction: Mason Allen Owen Vivian is <EOS> Richard is Sullivan
#
# epoch 23 batch# 6 batch loss: -0.005132294230861589 80.0% samples processed
# question <SOS> What is her name <EOS>
# answer: Her name is Stella Phillips <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Mason <EOS> Eleanor Vivian Vivian Vivian Vivian Kelle
#
# epoch 23 batch# 8 batch loss: -0.005158895917702466 100.0% samples processed
# question <SOS> What is her name <EOS>
# answer: His name is Richard Parker <EOS> <PAD> <PAD> <PAD>
# prediction: Mason <EOS> <EOS> Eleanor Cherry <EOS> Vincent Carter Carter
#
# epoch 24 batch# 0 batch loss: -0.00514899029803928 20.0% samples processed
# question <SOS> What is your name <EOS>
# answer: y name is Arthur Carte <EOS> <PAD> <PAD> <PAD>
# prediction: Mason <EOS> <EOS> Eleanor Eleanor Sullivan Eleanor Sullivan <EOS>
#
# epoch 24 batch# 2 batch loss: -0.005109340418130159 40.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Dale Phillips <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# prediction: Mason <EOS> Vivian is <EOS> <EOS> Kelle Stuart Warre
#
# epoch 24 batch# 4 batch loss: -0.00503435819700826 60.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Our name is Dominik Allen and Camila Allen <EOS>
# prediction: Mason Allen <EOS> Carte Carte Kelle Sullivan Sullivan Ada
#
# epoch 24 batch# 6 batch loss: -0.005152418205398135 80.0% samples processed
# question <SOS> What is her name <EOS>
# answer: Her name is Stella Phillips <EOS> <PAD> <PAD> <PAD>
# prediction: Mason <EOS> Eleanor <EOS> Carte Kelle Sullivan <EOS> Eleanor
#
# epoch 24 batch# 8 batch loss: -0.005196605823584832 100.0% samples processed
# question <SOS> What is her name <EOS>
# answer: His name is Richard Parker <EOS> <PAD> <PAD> <PAD>
# prediction: Mason <EOS> <EOS> <EOS> <EOS> Cherry <EOS> Vincent Carte
#
# epoch 25 batch# 0 batch loss: -0.005116635162266903 20.0% samples processed
# question <SOS> What is your name <EOS>
# answer: y name is Arthur Carte <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Richards Davi <EOS> <EOS> Kelle Eleanor Sullivan <EOS>
#
# epoch 25 batch# 2 batch loss: -0.005105150019517168 40.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Dale Phillips <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# prediction: Mason is <EOS> Carte Kelle Sullivan Stuart Carter Kelle
#
# epoch 25 batch# 4 batch loss: -0.0050294035172555596 60.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Our name is Dominik Allen and Camila Allen <EOS>
# prediction: Mason <EOS> <EOS> Eleanor Carte William Vincent Annabella Owen
#
# epoch 25 batch# 6 batch loss: -0.005182109249290079 80.0% samples processed
# question <SOS> What is her name <EOS>
# answer: Her name is Stella Phillips <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Mason Dougla <EOS> Carte Kelle Sullivan Stuart Stuart
#
# epoch 25 batch# 8 batch loss: -0.005214744902332313 100.0% samples processed
# question <SOS> What is her name <EOS>
# answer: His name is Richard Parker <EOS> <PAD> <PAD> <PAD>
# prediction: Mason <EOS> Eleanor Sullivan <EOS> Cherry <EOS> Carte Kelle
#
# epoch 26 batch# 0 batch loss: -0.0051117789262207225 20.0% samples processed
# question <SOS> What is your name <EOS>
# answer: y name is Arthur Carte <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Richards Davi <EOS> Stuart Kelle Sullivan Stuart Kelle
#
# epoch 26 batch# 2 batch loss: -0.0051221531321061775 40.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Dale Phillips <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# prediction: Mason is <EOS> Carte Kelle Kelle Stuart Stuart Stuart
#
# epoch 26 batch# 4 batch loss: -0.005053720233263448 60.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Our name is Dominik Allen and Camila Allen <EOS>
# prediction: Mason <EOS> <EOS> Eleanor Sullivan Adam Vincent Annabella Owen
#
# epoch 26 batch# 6 batch loss: -0.005147497344296426 80.0% samples processed
# question <SOS> What is her name <EOS>
# answer: Her name is Stella Phillips <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Mason Dougla Richard <EOS> <EOS> Vincent Carter Kelle
#
# epoch 26 batch# 8 batch loss: -0.005229802831308916 100.0% samples processed
# question <SOS> What is her name <EOS>
# answer: His name is Richard Parker <EOS> <PAD> <PAD> <PAD>
# prediction: Mason <EOS> Eleanor Sullivan <EOS> Eleanor Clar Brook Sullivan
#
# epoch 27 batch# 0 batch loss: -0.0051489131728885695 20.0% samples processed
# question <SOS> What is your name <EOS>
# answer: y name is Arthur Carte <EOS> <PAD> <PAD> <PAD>
# prediction: Mason <EOS> Eleanor Sullivan Richards Vincent Vincent Annabella Vincent
#
# epoch 27 batch# 2 batch loss: -0.005175482307095081 40.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Dale Phillips <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# prediction: Mason <EOS> Vivian Eleanor Sullivan Sullivan Stuart Warre Kelle
#
# epoch 27 batch# 4 batch loss: -0.005038314498960972 60.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Our name is Dominik Allen and Camila Allen <EOS>
# prediction: Mason Allen <EOS> <EOS> <EOS> William Robert Sullivan Sawyer
#
# epoch 27 batch# 6 batch loss: -0.005200941319344565 80.0% samples processed
# question <SOS> What is her name <EOS>
# answer: Her name is Stella Phillips <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Mason Dougla <EOS> Fowle Vivian Vincent Annabella Vincent
#
# epoch 27 batch# 8 batch loss: -0.0052307978039607406 100.0% samples processed
# question <SOS> What is her name <EOS>
# answer: His name is Richard Parker <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Richard Stella <EOS> <EOS> Cherry <EOS> Carte Stuart
#
# epoch 28 batch# 0 batch loss: -0.0051761108479695395 20.0% samples processed
# question <SOS> What is your name <EOS>
# answer: y name is Arthur Carte <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Richards Richards Richards Richards Vincent James Annabella Vincent
#
# epoch 28 batch# 2 batch loss: -0.00513443406089209 40.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Dale Phillips <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# prediction: Mason <EOS> Vivian Eleanor Carte Stuart Carter Kelle Kelle
#
# epoch 28 batch# 4 batch loss: -0.005063571079517715 60.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Our name is Dominik Allen and Camila Allen <EOS>
# prediction: Mason Allen <EOS> <EOS> <EOS> Carte Vincent is Brianna
#
# epoch 28 batch# 6 batch loss: -0.005207521622651257 80.0% samples processed
# question <SOS> What is her name <EOS>
# answer: Her name is Stella Phillips <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Mason Dougla Richard <EOS> <EOS> Vincent Carter Stuart
#
# epoch 28 batch# 8 batch loss: -0.0052162791398586705 100.0% samples processed
# question <SOS> What is her name <EOS>
# answer: His name is Richard Parker <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Richard <EOS> Carte Kelle Sullivan Eleanor Sullivan Sullivan
#
# epoch 29 batch# 0 batch loss: -0.00516793251154013 20.0% samples processed
# question <SOS> What is your name <EOS>
# answer: y name is Arthur Carte <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Richards Richards Richards Richards Vincent Thoma Annabella Annabella
#
# epoch 29 batch# 2 batch loss: -0.005170676115085371 40.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Dale Phillips <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# prediction: Mason <EOS> Vivian is <EOS> <EOS> Eleanor Sullivan <EOS>
#
# epoch 29 batch# 4 batch loss: -0.00506481910997536 60.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Our name is Dominik Allen and Camila Allen <EOS>
# prediction: Mason <EOS> Eleanor <EOS> Carte Kelle Sullivan Sullivan Taylo
#
# epoch 29 batch# 6 batch loss: -0.005250193949905224 80.0% samples processed
# question <SOS> What is her name <EOS>
# answer: Her name is Stella Phillips <EOS> <PAD> <PAD> <PAD>
# prediction: Mason <EOS> Eleanor Sullivan Morris Vivian Vincent Eleanor Sullivan
#
# epoch 29 batch# 8 batch loss: -0.005256140444544144 100.0% samples processed
# question <SOS> What is her name <EOS>
# answer: His name is Richard Parker <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Richard <EOS> Carte Kelle <EOS> Carte Carte Kelle
#
# epoch 30 batch# 0 batch loss: -0.005225290689850226 20.0% samples processed
# question <SOS> What is your name <EOS>
# answer: y name is Arthur Carte <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Richards Davi <EOS> <EOS> Kelle Sullivan Stuart Carter
#
# epoch 30 batch# 2 batch loss: -0.005210368617554195 40.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Dale Phillips <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# prediction: Mason is <EOS> <EOS> Eleanor Sullivan <EOS> Brook Brook
#
# epoch 30 batch# 4 batch loss: -0.005077165420516394 60.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Our name is Dominik Allen and Camila Allen <EOS>
# prediction: Mason <EOS> Eleanor Sullivan <EOS> Eleanor Vincent is Brianna
#
# epoch 30 batch# 6 batch loss: -0.005250086178421043 80.0% samples processed
# question <SOS> What is her name <EOS>
# answer: Her name is Stella Phillips <EOS> <PAD> <PAD> <PAD>
# prediction: Mason <EOS> <EOS> Eleanor Sullivan <EOS> Eleanor name Marcus
#
# epoch 30 batch# 8 batch loss: -0.005252195071079768 100.0% samples processed
# question <SOS> What is her name <EOS>
# answer: His name is Richard Parker <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Richard Stella Ada Her Higgin Carte Carte Kelle
#
# epoch 31 batch# 0 batch loss: -0.005225925036938861 20.0% samples processed
# question <SOS> What is your name <EOS>
# answer: y name is Arthur Carte <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Richards Davi Morris Richards Richards Vincent Annabella Annabella
#
# epoch 31 batch# 2 batch loss: -0.0052223383681848645 40.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Dale Phillips <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# prediction: Mason is Stella Vivian James Kelle Vivian Stuart Carter
#
# epoch 31 batch# 4 batch loss: -0.005102385912323371 60.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Our name is Dominik Allen and Camila Allen <EOS>
# prediction: Mason <EOS> Eleanor <EOS> Carte Kelly Kelly Cherry William
#
# epoch 31 batch# 6 batch loss: -0.00526907920720987 80.0% samples processed
# question <SOS> What is her name <EOS>
# answer: Her name is Stella Phillips <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Mason <EOS> <EOS> <EOS> Vivian is Kelle Kelle
#
# epoch 31 batch# 8 batch loss: -0.0053107085841475055 100.0% samples processed
# question <SOS> What is her name <EOS>
# answer: His name is Richard Parker <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Richard Stella <EOS> <EOS> <EOS> Carte Carte Kelle
#
# epoch 32 batch# 0 batch loss: -0.00523714603332337 20.0% samples processed
# question <SOS> What is your name <EOS>
# answer: y name is Arthur Carte <EOS> <PAD> <PAD> <PAD>
# prediction: Mason <EOS> Eleanor <EOS> Carte Kelle Sullivan Stuart Carter
#
# epoch 32 batch# 2 batch loss: -0.005264064355287701 40.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Dale Phillips <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# prediction: Mason is <EOS> <EOS> Kelle Sullivan Stuart Carter Kelle
#
# epoch 32 batch# 4 batch loss: -0.0051404659752734005 60.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Our name is Dominik Allen and Camila Allen <EOS>
# prediction: Mason <EOS> Eleanor <EOS> <EOS> Eleanor Sullivan <EOS> Eleanor
#
# epoch 32 batch# 6 batch loss: -0.005300937074935064 80.0% samples processed
# question <SOS> What is her name <EOS>
# answer: Her name is Stella Phillips <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Mason <EOS> <EOS> <EOS> Eleanor Eleanor Sullivan <EOS>
#
# epoch 32 batch# 8 batch loss: -0.005302663848851807 100.0% samples processed
# question <SOS> What is her name <EOS>
# answer: His name is Richard Parker <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Richard <EOS> Carte Kelle <EOS> Carte Carte Kelle
#
# epoch 33 batch# 0 batch loss: -0.005238700978225097 20.0% samples processed
# question <SOS> What is your name <EOS>
# answer: y name is Arthur Carte <EOS> <PAD> <PAD> <PAD>
# prediction: Mason <EOS> <EOS> Eleanor Eleanor Sullivan Eleanor Carte Stuart
#
# epoch 33 batch# 2 batch loss: -0.005289677719702013 40.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Dale Phillips <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# prediction: Mason is Stella Vivian Vivian Vivian James Morris Kelle
#
# epoch 33 batch# 4 batch loss: -0.005106362557853572 60.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Our name is Dominik Allen and Camila Allen <EOS>
# prediction: Mason Allen Owen <EOS> <EOS> Carte Vincent is Sullivan
#
# epoch 33 batch# 6 batch loss: -0.005316757393302396 80.0% samples processed
# question <SOS> What is her name <EOS>
# answer: Her name is Stella Phillips <EOS> <PAD> <PAD> <PAD>
# prediction: Mason <EOS> <EOS> <EOS> <EOS> Vivian James Morris Kelle
#
# epoch 33 batch# 8 batch loss: -0.00532254196878057 100.0% samples processed
# question <SOS> What is her name <EOS>
# answer: His name is Richard Parker <EOS> <PAD> <PAD> <PAD>
# prediction: Mason <EOS> Eleanor Sullivan <EOS> Cherry <EOS> Vincent Carte
#
# epoch 34 batch# 0 batch loss: -0.005287293985020369 20.0% samples processed
# question <SOS> What is your name <EOS>
# answer: y name is Arthur Carte <EOS> <PAD> <PAD> <PAD>
# prediction: Mason <EOS> Eleanor Sullivan <EOS> <EOS> Eleanor Sullivan <EOS>
#
# epoch 34 batch# 2 batch loss: -0.005279565026285127 40.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Dale Phillips <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# prediction: Mason <EOS> Vivian Eleanor Sullivan <EOS> Brook Ellis Ellis
#
# epoch 34 batch# 4 batch loss: -0.005101925373310223 60.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Our name is Dominik Allen and Camila Allen <EOS>
# prediction: Mason Allen <EOS> Carte Carte Kelly Carte Carte Kelly
#
# epoch 34 batch# 6 batch loss: -0.005284353028400801 80.0% samples processed
# question <SOS> What is her name <EOS>
# answer: Her name is Stella Phillips <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Mason <EOS> <EOS> <EOS> Vivian James Vivian Kelle
#
# epoch 34 batch# 8 batch loss: -0.00534637896635104 100.0% samples processed
# question <SOS> What is her name <EOS>
# answer: His name is Richard Parker <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Richard Stella Ada Her Carter Mason <EOS> Eleanor
#
# epoch 35 batch# 0 batch loss: -0.005289443550282158 20.0% samples processed
# question <SOS> What is your name <EOS>
# answer: y name is Arthur Carte <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Richards <EOS> <EOS> Stuart Kelle Eleanor Sullivan Brook
#
# epoch 35 batch# 2 batch loss: -0.0053256406099535525 40.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Dale Phillips <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# prediction: Mason is <EOS> <EOS> Kelle Stuart Stuart Warre Higgin
#
# epoch 35 batch# 4 batch loss: -0.005120737536344677 60.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Our name is Dominik Allen and Camila Allen <EOS>
# prediction: Mason <EOS> Eleanor <EOS> <EOS> Eleanor Vincent is Sullivan
#
# epoch 35 batch# 6 batch loss: -0.00534610211616382 80.0% samples processed
# question <SOS> What is her name <EOS>
# answer: Her name is Stella Phillips <EOS> <PAD> <PAD> <PAD>
# prediction: Mason <EOS> <EOS> Eleanor Sullivan <EOS> Eleanor name Brook
#
# epoch 35 batch# 8 batch loss: -0.005389074562117457 100.0% samples processed
# question <SOS> What is her name <EOS>
# answer: His name is Richard Parker <EOS> <PAD> <PAD> <PAD>
# prediction: Mason <EOS> Eleanor Sullivan <EOS> Carte Carte Kelle Kelle
#
# epoch 36 batch# 0 batch loss: -0.005346974547137506 20.0% samples processed
# question <SOS> What is your name <EOS>
# answer: y name is Arthur Carte <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Richards is <EOS> Stuart Kelle Eleanor Sullivan Brook
#
# epoch 36 batch# 2 batch loss: -0.005300298449583352 40.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Dale Phillips <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# prediction: Mason <EOS> Vivian is Vivian Kelle Vivian Stuart Stuart
#
# epoch 36 batch# 4 batch loss: -0.00508887974137906 60.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Our name is Dominik Allen and Camila Allen <EOS>
# prediction: Mason <EOS> Eleanor <EOS> <EOS> Kelly Kelly Higgin William
#
# epoch 36 batch# 6 batch loss: -0.005327247068635188 80.0% samples processed
# question <SOS> What is her name <EOS>
# answer: Her name is Stella Phillips <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Mason <EOS> <EOS> <EOS> Eleanor Sullivan <EOS> Eleanor
#
# epoch 36 batch# 8 batch loss: -0.005400294641731307 100.0% samples processed
# question <SOS> What is her name <EOS>
# answer: His name is Richard Parker <EOS> <PAD> <PAD> <PAD>
# prediction: Mason <EOS> <EOS> <EOS> <EOS> Eleanor Sullivan Sullivan Brook
#
# epoch 37 batch# 0 batch loss: -0.005345036362996325 20.0% samples processed
# question <SOS> What is your name <EOS>
# answer: y name is Arthur Carte <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Richards is <EOS> <EOS> Kelle Sullivan <EOS> Brook
#
# epoch 37 batch# 2 batch loss: -0.005386450022342615 40.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Dale Phillips <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# prediction: Mason <EOS> Eleanor Eleanor Sullivan Sullivan Brook Brook Ellis
#
# epoch 37 batch# 4 batch loss: -0.005110155005240813 60.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Our name is Dominik Allen and Camila Allen <EOS>
# prediction: Mason <EOS> Eleanor <EOS> <EOS> Eleanor Sullivan <EOS> William
#
# epoch 37 batch# 6 batch loss: -0.005356492489227094 80.0% samples processed
# question <SOS> What is her name <EOS>
# answer: Her name is Stella Phillips <EOS> <PAD> <PAD> <PAD>
# prediction: Mason <EOS> <EOS> Eleanor Vivian Vivian Vincent Vivian Vivian
#
# epoch 37 batch# 8 batch loss: -0.005423476031864993 100.0% samples processed
# question <SOS> What is her name <EOS>
# answer: His name is Richard Parker <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Richard <EOS> <EOS> <EOS> Carte Eleanor Carte Stuart
#
# epoch 38 batch# 0 batch loss: -0.005364580967579968 20.0% samples processed
# question <SOS> What is your name <EOS>
# answer: y name is Arthur Carte <EOS> <PAD> <PAD> <PAD>
# prediction: Mason <EOS> Eleanor <EOS> <EOS> Kelle Sullivan <EOS> Eleanor
#
# ...
# question <SOS> What is your name <EOS>
# answer: y name is Arthur Carte <EOS> <PAD> <PAD> <PAD>
# prediction: Mason <EOS> Eleanor <EOS> <EOS> Eleanor Eleanor Carte Tess
#
# epoch 39 batch# 2 batch loss: -0.00541576583054848 40.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Dale Phillips <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# prediction: Mason is <EOS> <EOS> Kelle Stuart Stuart Stuart Stuart
#
# epoch 39 batch# 4 batch loss: -0.005149243661435321 60.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Our name is Dominik Allen and Camila Allen <EOS>
# prediction: Mason is <EOS> <EOS> <EOS> Carte Vincent Annabella Vincent
#
# epoch 39 batch# 6 batch loss: -0.005394008592702448 80.0% samples processed
# question <SOS> What is her name <EOS>
# answer: Her name is Stella Phillips <EOS> <PAD> <PAD> <PAD>
# prediction: Mason <EOS> <EOS> <EOS> <EOS> Carte Kelle Sullivan Stuart
#
# epoch 39 batch# 8 batch loss: -0.0054960736888460815 100.0% samples processed
# question <SOS> What is her name <EOS>
# answer: His name is Richard Parker <EOS> <PAD> <PAD> <PAD>
# prediction: Mason <EOS> Eleanor name <EOS> <EOS> <EOS> Vincent Robert
#
# epoch 40 batch# 0 batch loss: -0.005425365816336125 20.0% samples processed
# question <SOS> What is your name <EOS>
# answer: y name is Arthur Carte <EOS> <PAD> <PAD> <PAD>
# prediction: Mason <EOS> <EOS> Eleanor Eleanor Kelle Sullivan <EOS> Eleanor
#
# epoch 40 batch# 2 batch loss: -0.005410829428001307 40.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Dale Phillips <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# prediction: Mason <EOS> Vivian is <EOS> Kelle Sullivan Stuart Carter
#
# epoch 40 batch# 4 batch loss: -0.005180922860745341 60.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Our name is Dominik Allen and Camila Allen <EOS>
# prediction: Mason <EOS> <EOS> Eleanor Carte William Eleanor Sullivan Owen
#
# epoch 40 batch# 6 batch loss: -0.005402137729106471 80.0% samples processed
# question <SOS> What is her name <EOS>
# answer: Her name is Stella Phillips <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Mason <EOS> <EOS> <EOS> Eleanor Eleanor Patrick Sullivan
#
# epoch 40 batch# 8 batch loss: -0.0054955672967480496 100.0% samples processed
# question <SOS> What is her name <EOS>
# answer: His name is Richard Parker <EOS> <PAD> <PAD> <PAD>
# prediction: Mason <EOS> Eleanor name <EOS> Eleanor Sullivan <EOS> Eleanor
#
# epoch 41 batch# 0 batch loss: -0.005442268375190906 20.0% samples processed
# question <SOS> What is your name <EOS>
# answer: y name is Arthur Carte <EOS> <PAD> <PAD> <PAD>
# prediction: Mason <EOS> Eleanor <EOS> <EOS> <EOS> Eleanor Sullivan <EOS>
#
# epoch 41 batch# 2 batch loss: -0.005417297637904994 40.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Dale Phillips <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# prediction: Mason is is <EOS> Stuart Kelle <EOS> Kelle Sullivan
#
# epoch 41 batch# 4 batch loss: -0.005115368345286697 60.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Our name is Dominik Allen and Camila Allen <EOS>
# prediction: Mason <EOS> <EOS> Eleanor Carte William Vincent is Brianna
#
# epoch 41 batch# 6 batch loss: -0.005400408539571799 80.0% samples processed
# question <SOS> What is her name <EOS>
# answer: Her name is Stella Phillips <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Mason <EOS> <EOS> <EOS> Vivian Vincent Annabella Vincent
#
# epoch 41 batch# 8 batch loss: -0.00551512892707251 100.0% samples processed
# question <SOS> What is her name <EOS>
# answer: His name is Richard Parker <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Richard <EOS> Carte Carte Kelle Sullivan Stuart Stuart
#
# epoch 42 batch# 0 batch loss: -0.005454346159240231 20.0% samples processed
# question <SOS> What is your name <EOS>
# answer: y name is Arthur Carte <EOS> <PAD> <PAD> <PAD>
# prediction: Mason <EOS> Eleanor name Richards Kelle Eleanor Sullivan <EOS>
#
# epoch 42 batch# 2 batch loss: -0.0054169429204193875 40.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Dale Phillips <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# prediction: Mason is is <EOS> <EOS> Eleanor Sullivan Sullivan Brook
#
# epoch 42 batch# 4 batch loss: -0.005196723897824995 60.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Our name is Dominik Allen and Camila Allen <EOS>
# prediction: Mason is <EOS> <EOS> <EOS> William Robert Phillips Eleanor
#
# epoch 42 batch# 6 batch loss: -0.005428143165772781 80.0% samples processed
# question <SOS> What is her name <EOS>
# answer: Her name is Stella Phillips <EOS> <PAD> <PAD> <PAD>
# prediction: Mason <EOS> <EOS> Eleanor Vivian Vivian is <PAD> <PAD>
#
# epoch 42 batch# 8 batch loss: -0.005536704731639475 100.0% samples processed
# question <SOS> What is her name <EOS>
# answer: His name is Richard Parker <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Richard <EOS> Carte <EOS> <EOS> <EOS> Carte Kelle
#
# epoch 43 batch# 0 batch loss: -0.005500301587744616 20.0% samples processed
# question <SOS> What is your name <EOS>
# answer: y name is Arthur Carte <EOS> <PAD> <PAD> <PAD>
# prediction: Mason <EOS> Eleanor name <EOS> Eleanor name Sullivan <PAD>
#
# epoch 43 batch# 2 batch loss: -0.005475622310768813 40.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Dale Phillips <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# prediction: Mason <EOS> Eleanor name Sullivan <PAD> <PAD> Stuart Warre
#
# epoch 43 batch# 4 batch loss: -0.005191736971028149 60.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Our name is Dominik Allen and Camila Allen <EOS>
# prediction: Mason is <EOS> <EOS> Eleanor Sullivan <EOS> Eleanor name
#
# epoch 43 batch# 6 batch loss: -0.0054664649796905 80.0% samples processed
# question <SOS> What is her name <EOS>
# answer: Her name is Stella Phillips <EOS> <PAD> <PAD> <PAD>
# prediction: Mason <EOS> <EOS> Eleanor Vivian Vivian Vincent <PAD> <PAD>
#
# epoch 43 batch# 8 batch loss: -0.005520727310795337 100.0% samples processed
# question <SOS> What is her name <EOS>
# answer: His name is Richard Parker <EOS> <PAD> <PAD> <PAD>
# prediction: Mason <EOS> Eleanor name <EOS> Eleanor name Sullivan <PAD>
#
# epoch 44 batch# 0 batch loss: -0.005551164998905733 20.0% samples processed
# question <SOS> What is your name <EOS>
# answer: y name is Arthur Carte <EOS> <PAD> <PAD> <PAD>
# prediction: Mason <EOS> Eleanor <EOS> Stuart Kelle <EOS> Stuart Stuart
#
# epoch 44 batch# 2 batch loss: -0.005532272887649015 40.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Dale Phillips <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# prediction: Mason is <EOS> <EOS> Eleanor Carte Kelle <PAD> <PAD>
#
# epoch 44 batch# 4 batch loss: -0.005192043681745417 60.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Our name is Dominik Allen and Camila Allen <EOS>
# prediction: Mason is <EOS> Carte Carte Kelle Sullivan <EOS> William
#
# epoch 44 batch# 6 batch loss: -0.005504582019057125 80.0% samples processed
# question <SOS> What is her name <EOS>
# answer: Her name is Stella Phillips <EOS> <PAD> <PAD> <PAD>
# prediction: Mason is <EOS> <EOS> <EOS> Vivian Vincent James Annabella
#
# epoch 44 batch# 8 batch loss: -0.005586260580457747 100.0% samples processed
# question <SOS> What is her name <EOS>
# answer: His name is Richard Parker <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Richard <EOS> Carte <EOS> Carte Vincent is <EOS>
#
# epoch 45 batch# 0 batch loss: -0.005514086602488533 20.0% samples processed
# question <SOS> What is your name <EOS>
# answer: y name is Arthur Carte <EOS> <PAD> <PAD> <PAD>
# prediction: Mason is <EOS> <EOS> Stuart Cadie Carte Kelle <EOS>
#
# epoch 45 batch# 2 batch loss: -0.005559502518735826 40.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Dale Phillips <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# prediction: Mason <EOS> Eleanor name <EOS> Eleanor name <EOS> Davi
#
# epoch 45 batch# 4 batch loss: -0.005180863197892904 60.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Our name is Dominik Allen and Camila Allen <EOS>
# prediction: Mason <EOS> <EOS> <EOS> <EOS> William Robert Phillips Carter
#
# epoch 45 batch# 6 batch loss: -0.005488517650519498 80.0% samples processed
# question <SOS> What is her name <EOS>
# answer: Her name is Stella Phillips <EOS> <PAD> <PAD> <PAD>
# prediction: Mason is <EOS> <EOS> <EOS> <EOS> Vincent <PAD> <PAD>
#
# epoch 45 batch# 8 batch loss: -0.005604032528935932 100.0% samples processed
# question <SOS> What is her name <EOS>
# answer: His name is Richard Parker <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Richard <EOS> <EOS> <EOS> Cherry <EOS> Carte <PAD>
#
# epoch 46 batch# 0 batch loss: -0.005578010153840296 20.0% samples processed
# question <SOS> What is your name <EOS>
# answer: y name is Arthur Carte <EOS> <PAD> <PAD> <PAD>
# prediction: Mason is is <EOS> Stuart Fowle Carte Kelle Kelle
#
# epoch 46 batch# 2 batch loss: -0.005582311423495412 40.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Dale Phillips <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# prediction: Mason name <EOS> Eleanor name <EOS> Carte Carte <PAD>
#
# epoch 46 batch# 4 batch loss: -0.005211669355048798 60.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Our name is Dominik Allen and Camila Allen <EOS>
# prediction: Mason name <EOS> Eleanor Carte Kelle Sullivan <EOS> Eleanor
#
# epoch 46 batch# 6 batch loss: -0.005510979870450683 80.0% samples processed
# question <SOS> What is her name <EOS>
# answer: Her name is Stella Phillips <EOS> <PAD> <PAD> <PAD>
# prediction: Mason is <EOS> <EOS> <EOS> <EOS> Vincent <PAD> <PAD>
#
# epoch 46 batch# 8 batch loss: -0.005620517578790896 100.0% samples processed
# question <SOS> What is her name <EOS>
# answer: His name is Richard Parker <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Richard <EOS> Carte Carte Kelle Sullivan <EOS> Eleanor
#
# epoch 47 batch# 0 batch loss: -0.005529772257432342 20.0% samples processed
# question <SOS> What is your name <EOS>
# answer: y name is Arthur Carte <EOS> <PAD> <PAD> <PAD>
# prediction: Mason is <EOS> <EOS> <EOS> Eleanor Eleanor <PAD> <PAD>
#
# epoch 47 batch# 2 batch loss: -0.0056560516386525705 40.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Dale Phillips <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# prediction: Mason is is <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
#
# epoch 47 batch# 4 batch loss: -0.005176945545827039 60.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Our name is Dominik Allen and Camila Allen <EOS>
# prediction: Mason name <EOS> <EOS> <EOS> Eleanor name Patrick Brianna
#
# epoch 47 batch# 6 batch loss: -0.005586455023149028 80.0% samples processed
# question <SOS> What is her name <EOS>
# answer: Her name is Stella Phillips <EOS> <PAD> <PAD> <PAD>
# prediction: Mason name <EOS> <EOS> <EOS> Vivian is <PAD> <PAD>
#
# epoch 47 batch# 8 batch loss: -0.00562339456519112 100.0% samples processed
# question <SOS> What is her name <EOS>
# answer: His name is Richard Parker <EOS> <PAD> <PAD> <PAD>
# prediction: Mason name <EOS> <EOS> <EOS> <EOS> <EOS> Vincent Robert
#
# epoch 48 batch# 0 batch loss: -0.0055728405131958425 20.0% samples processed
# question <SOS> What is your name <EOS>
# answer: y name is Arthur Carte <EOS> <PAD> <PAD> <PAD>
# prediction: Mason is <EOS> <EOS> Richards <EOS> Vincent Robert is
#
# epoch 48 batch# 2 batch loss: -0.005697907414287329 40.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Dale Phillips <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# prediction: Mason is <EOS> <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
#
# epoch 48 batch# 4 batch loss: -0.0052256248309277 60.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Our name is Dominik Allen and Camila Allen <EOS>
# prediction: Mason is <EOS> <EOS> <EOS> is Vincent is Brianna
#
# epoch 48 batch# 6 batch loss: -0.005552991904551163 80.0% samples processed
# question <SOS> What is her name <EOS>
# answer: Her name is Stella Phillips <EOS> <PAD> <PAD> <PAD>
# prediction: Mason is <EOS> <EOS> Eleanor is Vincent James Cherry
#
# epoch 48 batch# 8 batch loss: -0.005680245012626983 100.0% samples processed
# question <SOS> What is her name <EOS>
# answer: His name is Richard Parker <EOS> <PAD> <PAD> <PAD>
# prediction: Mason Richard <EOS> <EOS> <EOS> <EOS> <EOS> <PAD> <PAD>
#
# epoch 49 batch# 0 batch loss: -0.00561761726567056 20.0% samples processed
# question <SOS> What is your name <EOS>
# answer: y name is Arthur Carte <EOS> <PAD> <PAD> <PAD>
# prediction: Mason name <EOS> <EOS> <EOS> <EOS> Eleanor Sullivan <PAD>
#
# epoch 49 batch# 2 batch loss: -0.00573806423926726 40.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Dale Phillips <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# prediction: Mason name <EOS> Eleanor name <PAD> <PAD> <PAD> <PAD>
#
# epoch 49 batch# 4 batch loss: -0.005240306563791819 60.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Our name is Dominik Allen and Camila Allen <EOS>
# prediction: Mason is <EOS> <EOS> Eleanor Sullivan <EOS> Eleanor name
#
# epoch 49 batch# 6 batch loss: -0.00559239400899969 80.0% samples processed
# question <SOS> What is her name <EOS>
# answer: Her name is Stella Phillips <EOS> <PAD> <PAD> <PAD>
# prediction: Mason name <EOS> Eleanor name <EOS> Eleanor <PAD> <PAD>
#
# epoch 49 batch# 8 batch loss: -0.005720104541978799 100.0% samples processed
# question <SOS> What is her name <EOS>
# answer: His name is Richard Parker <EOS> <PAD> <PAD> <PAD>
# prediction: Mason name <EOS> Eleanor <EOS> Carte Carte Kelle <PAD>
#
# epoch 50 batch# 0 batch loss: -0.005659627335262485 20.0% samples processed
# question <SOS> What is your name <EOS>
# answer: y name is Arthur Carte <EOS> <PAD> <PAD> <PAD>
# prediction: Mason is <EOS> <EOS> Richards Kelle <EOS> Stuart Kelle
#
# epoch 50 batch# 2 batch loss: -0.00571252522058785 40.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Dale Phillips <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# prediction: Mason is is <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
#
# epoch 50 batch# 4 batch loss: -0.005163890542462468 60.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Our name is Dominik Allen and Camila Allen <EOS>
# prediction: <EOS> Carte <EOS> Vincent Carte Carte Brook Sullivan <EOS>
#
# epoch 50 batch# 6 batch loss: -0.005625140212941915 80.0% samples processed
# question <SOS> What is her name <EOS>
# answer: Her name is Stella Phillips <EOS> <PAD> <PAD> <PAD>
# prediction: Mason is <EOS> <EOS> <EOS> <EOS> Eleanor name <EOS>
#
# epoch 50 batch# 8 batch loss: -0.005754421974415891 100.0% samples processed
# question <SOS> What is her name <EOS>
# answer: His name is Richard Parker <EOS> <PAD> <PAD> <PAD>
# prediction: Mason <EOS> <EOS> <EOS> <EOS> <EOS> <EOS> <PAD> <PAD>
#
# epoch 51 batch# 0 batch loss: -0.005612954235402867 20.0% samples processed
# question <SOS> What is your name <EOS>
# answer: y name is Arthur Carte <EOS> <PAD> <PAD> <PAD>
# prediction: <EOS> is <EOS> <EOS> Eleanor Sullivan <EOS> <PAD> <PAD>
#
# epoch 51 batch# 2 batch loss: -0.005682654606061988 40.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Dale Phillips <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# prediction: <EOS> Carte is <EOS> <EOS> Eleanor name <EOS> Carte
#
# epoch 51 batch# 4 batch loss: -0.005151520221261308 60.0% samples processed
# question <SOS> What is your name <EOS>
# answer: Our name is Dominik Allen and Camila Allen <EOS>
# prediction: <EOS> Carte Carte Carte Carte William Eleanor Sullivan Morris
#
# epoch 51 batch# 6 batch loss: -0.005526151988306083 80.0% samples processed
# question <SOS> What is her name <EOS>
# answer: Her name is Stella Phillips <EOS> <PAD> <PAD> <PAD>
# prediction: <EOS> Vincent Carte Carte Allen Ada Vincent Annabella <PAD>
#
# epoch 51 batch# 8 batch loss: -0.005726357194362208 100.0% samples processed
# question <SOS> What is her name <EOS>
# answer: His name is Richard Parker <EOS> <PAD> <PAD> <PAD>
# prediction: <EOS> Vincent Carte <EOS> <EOS> Carte <EOS> Vincent Robert

# %%
vocab_target.index

# %%
# from pathlib import Path

# questions = src.utils.tokenize_questions(questions, vocab_source)
# answers = src.utils.tokenize_answers(answers, vocab_target)

# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# is_cuda = torch.cuda.is_available()
# #is_cuda = False
# print("is cuda:",is_cuda)


# # hyperparams
# epochs = 1

# batch_size = 32
# hidden_size = 2
# lr = 0.01
# teacher_forcing_ratio = 0.5
# loader  = DataLoader(list(zip(questions, answers)), shuffle = False, batch_size = batch_size)
# print


# # model
# input_size = len(vocab_source.words)
# hidden_size = hidden_size
# output_size = len(vocab_target.words)
# model = Seq2Seq(input_size, hidden_size, output_size)


# if Path("./checkpoints/model_1.pt").is_file():
#     model.load_state_dict(torch.load("./checkpoints/model_1.pt"))
#     print("loading from checkpoint: ''./checkpoints/model_1.pt'")
# else:
#     print("nothing to load at checkpoint: './checkpoints/model_1.pt'")

# model.to(device)
# # training

# optim = torch.optim.SGD(model.parameters(), lr=lr)
# loss_fn = nn.NLLLoss()
# model.train()
# epoch = 0
# for epoch in range(epochs):

#     for batch_i, (questions, answers) in enumerate(loader):
#         batch_loss = 0
#         for q, a in zip(questions, answers):       
#             start = next(iter(torch.LongTensor([vocab_target.words["<SOS>"]])))
#             optim.zero_grad()
#             output = model(q,a,start)
            
#             rand = random.uniform(0,1)
#             loss = loss_fn(output, a.to(device))
#             loss.backward(retain_graph=True)
#             optim.step()
#             batch_loss += loss.item()
#             #print("loss:",loss.item())
#         if batch_i % 50 == 0:
#             share = round((batch_size * batch_i)/len(questions)*100,1)
#             print("batch#",batch_i,"batch loss:",batch_loss/batch_size, f"{share}% samples processed")
#         if batch_i % 200 == 0:
#             torch.save(model.state_dict(),"./checkpoints/model_1.pt")

# %%
print(qt)
print(trg)
print(hidden)

# %%
torch.cuda.memory_summary(device='cuda', abbreviated=False)

# %%
t = torch.Tensor(2)
#t = t.view(1,-1)
t.shape
t=t.view()
t

# %%
at = at.view(-1)
output = output.squeeze(0)
print(at.shape)
print(output.shape)
loss_fn(output,at)

# %%
for que in questions[:2]:
    for word in que:
        print(word.shape, word.view(-1).shape,word.view(1,-1).shape,word.view(1,-1), word.view(1,1,-1).shape)

# %%
import src.abc
src.abc.test()

# %%
import torch.nn.functional as F
F.one_hot(torch.Tensor([19]),50)
